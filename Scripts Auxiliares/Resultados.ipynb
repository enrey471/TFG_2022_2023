# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as pyplot
from scipy.optimize import curve_fit

# %%
# set up the figure
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlim(0,10)
ax.set_ylim(0,10)

# draw lines
xmin = 1
xmax = 9
y = 5
height = 1

plt.hlines(y, xmin, xmax)
plt.vlines(xmin, y - height / 2., y + height / 2.)
plt.vlines(xmax, y - height / 2., y + height / 2.)

# draw a point on the line
px = 4.3
plt.plot(px,y, 'ro', ms = 5, mfc = 'r')

# add numbers
plt.text(xmin + 0.6, y + 1, '3.604 ms', horizontalalignment='right')
plt.text(xmax - 0.6, y + 1, '11.587 ms', horizontalalignment='left')
plt.text(5.5, y + 0.6, '6.59 ± 0.3 ms', horizontalalignment='right')

plt.axis('off')
plt.show()

# %%
x = [-1.35322040e-05,
       -2.35555643e-05,
       -5.44308482e-05,
        6.78724635e-05,
        3.29889276e-05,
        4.65980279e-05,
        5.86190053e-05,
       -2.38025330e-05,
        4.22701793e-05,
        5.90818440e-05,
        3.25677731e-01,
        6.38227882e-05,
       -4.54271141e-05,
        4.60864200e-05,
        2.60878649e-01,
        3.67691121e-01,
        4.64783536e-05,
        6.05111941e-05,
        4.53049650e-02,
        8.39524372e-05]
categories = ['Albita', 'Alunita', 'Andesita', 'Buddingtonita', 'Calcita', 'Dickita', 'Diópsido', 'Hornblenda', 'Jarosita', 'Kaolinita', 'Kieserita', 'Labradorita', 'Malachita', 'Microclina', 'Monacita', 'Muscovita', 'Pirofilita', 'Pirrotina', 'Richterita', 'Serpentina']
categories.reverse()
plt.bar(categories, x, width=0.7, color = 'grey', edgecolor = 'black')
plt.xticks(categories, rotation=75)
plt.show()
